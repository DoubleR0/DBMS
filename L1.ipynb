# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json

# %%
dataset = pd.read_csv('data_round1_10000.csv')
# x = dataset['vitalsigns'].apply(pd.Series)
dataset = dataset.dropna(subset = ['vitalsigns'])
X = dataset.iloc[:, 13:14].values
# y = dataset.iloc[:, -1].values

# %%
print(X)
# Out:
# [["{'Systolic': '131', 'Pulses': '98', 'Respiration': '18', 'Temperature': '37.1', 'O2 Saturation': '99', 'Weight': '89.4', 'Diastolic': '82', 'BMI': '32.84', 'Height': '165'}"]
#  ["{'Weight (kg)': '16.2', 'Pain Location': 'none', 'BP Diastolic (mmHg)': '58', 'Nutritional status': 'Normal', 'BMI': '15.57', 'Assessed Tool': '02', 'Emotion': 'Appropriates', 'BP Systolic (mmHg)': '115', 'BP Means': '69', 'Level of conscious': 'Alert', 'Height (cm)': '102', 'Pulses': '126', 'Fall Risk': 'No', 'Infection risk assessment': 'SD', 'Triage Level': '03', 'Hx.of Drug Allergy': 'NKA', 'Hx.of Food Allergy  ': 'NKA', 'Temperature': '37', 'Respiration': '24', 'Status on Arrival': '01', 'Oxygen Saturation': '100'}"]
#  ["{'BMI': '22.598', 'Weight': '70', 'Temperature': '36.2', 'Respirations': '18', 'Pulse': '80', 'location': 'Eye Center', 'Height': '176', 'EWS Total': '0', 'Diastolic': '78', 'Systolic': '128'}"]
#  ...
#  ["{'Vision Left': '20', 'VA with contact Lens or glasses , Y or N': 'n', 'Systolic': '120', 'Temperature': '36.4', 'Respirations': '18', 'Pulse': '63', 'Height': '182', 'Diastolic': '73', 'BMI': '22.97', 'Vision Right': '20', 'Waist size (cm)': '91', 'Weight': '76.1'}"]
#  ["{'Body Mass Index': '31.47', 'Weight': '93.1', 'Respirations': '20', 'Temperature': '36.8', 'Height': '172', 'Pulse': '65', 'Diastolic': '77', 'Systolic': '166'}"]
#  ["{'Weight': 'ซื้อยา', 'location': 'Heart Clinic'}"]]

# %%
lis = list()
for i in range(len(X)):
            # X[i][0] = json.loads(str(X[i][0]).replace("'","\"").replace("Patient\"","Patient").replace("28.5\"", "28.5"))
    try:
        lis.append(json.loads(str(X[i][0]).replace("'","\"").replace("Patient\"","Patient").replace("28.5\"", "28.5")))
    except:
        np.delete(X, i, 0)
# for i in range(len(X)):
#     X[i][0] = str(X[i][0]).replace("\'","\"")
# for i in range(len(X)):
#     print(type(X[i][0]))
    # X[i][0] = json.loads(X[i][0])
# arr.append(i)
# X = map(str(i[0]).replace("\'","\""),)
# X[4][0] = json.loads(X[4][0])
# print(X[5])
# pd.json_normalize(X)

# %%
print(lis)
# Out:
# [{'Systolic': '131', 'Pulses': '98', 'Respiration': '18', 'Temperature': '37.1', 'O2 Saturation': '99', 'Weight': '89.4', 'Diastolic': '82', 'BMI': '32.84', 'Height': '165'}, {'Weight (kg)': '16.2', 'Pain Location': 'none', 'BP Diastolic (mmHg)': '58', 'Nutritional status': 'Normal', 'BMI': '15.57', 'Assessed Tool': '02', 'Emotion': 'Appropriates', 'BP Systolic (mmHg)': '115', 'BP Means': '69', 'Level of conscious': 'Alert', 'Height (cm)': '102', 'Pulses': '126', 'Fall Risk': 'No', 'Infection risk assessment': 'SD', 'Triage Level': '03', 'Hx.of Drug Allergy': 'NKA', 'Hx.of Food Allergy  ': 'NKA', 'Temperature': '37', 'Respiration': '24', 'Status on Arrival': '01', 'Oxygen Saturation': '100'}, {'BMI': '22.598', 'Weight': '70', 'Temperature': '36.2', 'Respirations': '18', 'Pulse': '80', 'location': 'Eye Center', 'Height': '176', 'EWS Total': '0', 'Diastolic': '78', 'Systolic': '128'}, {'Oxygen Saturation': '99', 'Height (cm)': '167', 'Pulses': '86', 'Pain Location': 'คอ', 'Status on Arrival': '01', 'Temperature': '36.5', 'Triage Level': '03', 'Weight (kg)': '67.9', 'Pain Score': '3', 'BP Systolic (mmHg)': '129', 'Respiration': '20', 'BP Diastolic (mmHg)': '89', 'BMI': '24.35', 'Assessed Tool': '01'}, {'BP Systolic (mmHg)': '109', 'BP Diastolic (mmHg)': '66', 'Assessed Tool': '01', 'Patient and Family Education(PFE) need': 'N', 'Fall Risk': 'No', 'Emotion': 'Appropriates', 'Oxygen Saturation': '97', 'Infection risk assessment': 'SD', 'Level of conscious': 'Alert', 'Status on Arrival': '01', 'Pulses': '82', 'Respiration': '18', 'Temperature': '36.9', 'Triage Level': '03'}, {'BP Systolic': '110', 'BP Diastolic': '54', 'Weight [kg]': '50.5', 'Respiration': '20', 'xPulse': '72'}, {'BMI': '15.42', 'Emotion': 'Appropriates', 'Area of risk': '02', 'Assessed Tool': '03', 'Hx.of Food Allergy  ': 'NKA', 'Hx.of Drug Allergy': 'NKA', 'Height (cm)': '55.5', 'Fall Risk': 'Yes and Advice', 'Pain Location': 'none', 'Infection risk assessment': 'SD', 'Triage Level': '03', 'Weight (kg)': '4.75', 'Level of conscious': 'Alert', 'Status on Arrival': '02', 'Temperature': '37'}, {'Status on Arrival': '01', 'Respiration': '16', 'BMI': '24.74', 'Pulses': '73', 'BP Diastolic (mmHg)': '75', 'Fall Risk': 'No', 'Emotion': 'Appropriates', 'BP Systolic (mmHg)': '125', 'Height (cm)': '167', 'Oxygen Saturation': '99', 'Weight (kg)': '69', 'Temperature': '36.5'}, {'Assessed Tool': '01', 'Emotion': 'Appropriates', 'BMI': '27.03', 'BP Diastolic (mmHg)': '69', 'BP Systolic (mmHg)': '127', 'BP Means': '82', 'Respiration': '20', 'Pulses': '95', 'Status on Arrival': '01', 'Fall Risk': 'No', 'Level of conscious': 'Alert', 'Patient and Family Education(PFE) need': 'Y', 'Oxygen Saturation': '100', 'Weight (kg)': '66.2', 'Triage Level': '03', 'Temperature': '36.8', 'Infection risk assessment': 'SD', 'Height (cm)': '156.5'}, {'Height (cm)': '77.5', 'Body Mass Index': '16.82', 'Weight [kg]': '10.1'}, {'BP Systolic (mmHg)': '143', 'BP Diastolic (mmHg)': '64', 'BMI': '26.08', 'Weight (kg)': '69.3', 'Fall Risk': 'No', 'Height (cm)': '163', 'Emotion': 'Appropriates', 'Triage Level': '05', 'Infection risk assessment': 'SD', 'Assessed Tool': '01', 'Temperature': '36.9', 'Status on Arrival': '01', 'Respiration': '18', 'Pulses': '94', 'Level of conscious': 'Alert', 'Oxygen Saturation': '95', 'Patient and Family Education(PFE) need': 'N'}, {'Temperature': '36.5', 'Systolic': '103', 'Weight': '53.9', 'Body Mass Index': '20.79', 'Respirations': '20', 'Height (cm)': '161', 'EWS Total': '1', 'Diastolic': '59', 'O2 Saturation': '100', 'Pulse': '57', 'MAP': '74'}, {'BMI': '24.03', 'location': 'Medicine Unit (แผนกอายุรกรรม)', 'Height': '158', 'Diastolic': '91', 'Systolic': '177', 'Pulse': '83', 'Respirations': '18', 'Temperature': '36.3', 'Weight': '60'}, {'location': 'Dermatology and Aesthetics Center(ศูนย์โรคผิวหนังและเวชสำอาง)'}, {'BP Means': '71', 'Temperature': '37.30', 'Respiration': '20', 'BP Diastolic (mmHg)': '61', 'Weight (kg)': '43.20', 'Pulses': '72', 'Fall Risk': 'No', 'Emotion ...

# %%
# for i in range(10):
#     print(type(X[i]))
pd.json_normalize(lis)
# Out:
#      Systolic Pulses Respiration Temperature O2 Saturation  Weight Diastolic  \
# 0         131     98          18        37.1            99    89.4        82
# 1         NaN    126          24          37           NaN     NaN       NaN
# 2         128    NaN         NaN        36.2           NaN      70        78
# 3         NaN     86          20        36.5           NaN     NaN       NaN
# 4         NaN     82          18        36.9           NaN     NaN       NaN
# ...       ...    ...         ...         ...           ...     ...       ...
# 7453      109    NaN         NaN        36.3           NaN    63.2        64
# 7454      NaN    NaN         NaN        37.3           NaN     NaN       NaN
# 7455      120    NaN         NaN        36.4           NaN    76.1        73
# 7456      166    NaN         NaN        36.8           NaN    93.1        77
# 7457      NaN    NaN         NaN         NaN           NaN  ซื้อยา       NaN
#
#          BMI Height Weight (kg)  ... CAVI: Left ABI: Right CAVI: Right  \
# 0      32.84    165         NaN  ...        NaN        NaN         NaN
# 1      15.57    NaN        16.2  ...        NaN        NaN         NaN
# 2     22.598    176         NaN  ...        NaN        NaN         NaN
# 3      24.35    NaN        67.9  ...        NaN        NaN         NaN
# 4        NaN    NaN         NaN  ...        NaN        NaN         NaN
# ...      ...    ...         ...  ...        ...        ...         ...
# 7453  25.640    157         NaN  ...        NaN        NaN         NaN
# 7454     NaN    NaN       8.650  ...        NaN        NaN         NaN
# 7455   22.97    182         NaN  ...        NaN        NaN         NaN
# 7456     NaN    172         NaN  ...        NaN        NaN         NaN
# 7457     NaN    NaN         NaN  ...        NaN        NaN         NaN
#
#      CAVI values: Left CAVI values: Right Eye Examination Foot Examination  \
# 0                  NaN                NaN             NaN              NaN
# 1                  NaN                NaN             NaN              NaN
# 2                  NaN                NaN             NaN              NaN
# 3                  NaN                NaN             NaN              NaN
# 4                  NaN                NaN             NaN              NaN
# ...                ...                ...             ...              ...
# 7453               NaN                NaN             NaN              NaN
# 7454               NaN                NaN             NaN              NaN
# 7455               NaN                NaN             NaN              NaN
# 7456               NaN                NaN             NaN              NaN
# 7457               NaN                NaN             NaN              NaN
#
#       LDL  BUN Creatinine
# 0     NaN  NaN        NaN
# 1     NaN  NaN        NaN
# 2     NaN  NaN        NaN
# 3     NaN  NaN        NaN
# 4     NaN  NaN        NaN
# ...   ...  ...        ...
# 7453  NaN  NaN        NaN
# 7454  NaN  NaN        NaN
# 7455  NaN  NaN        NaN
# 7456  NaN  NaN        NaN
# 7457  NaN  NaN        NaN
#
# [7458 rows x 187 columns]
